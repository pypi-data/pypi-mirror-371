# %%
from rich import print as rprint

# %%
import mlflow

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("Testing")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/785514504126471133', creation_time=1755920871238, experiment_id='785514504126471133', last_update_time=1755920871238, lifecycle_stage='active', name='Testing', tags={}>

# %% [markdown]
# ### Generate

# %% [markdown]
# #### Sync

# %%
from tinyloop.modules.generate import Generate
from pydantic import BaseModel
from typing import List


class Character(BaseModel):
    name: str
    description: str
    image: str


class Characters(BaseModel):
    characters: List[Character]


generate = Generate(
    model="openai/gpt-4.1-nano", temperature=0.1, output_format=Characters
)

response = generate(prompt="Give me 3 harry potter characters")
rprint(response)

# %% [markdown]
# #### Async

# %%
from tinyloop.modules.generate import Generate
from pydantic import BaseModel
from typing import List


class Character(BaseModel):
    name: str
    description: str
    image: str


class Characters(BaseModel):
    characters: List[Character]


generate = Generate(
    model="openai/gpt-4.1-nano", temperature=0.1, output_format=Characters
)

response = await generate.acall(prompt="Give me 3 harry potter characters")
rprint(response)

# %% [markdown]
# ### Tool Loop

# %% [markdown]
# #### Sync

# %%
from pydantic import BaseModel
import random
from tinyloop.features.function_calling import Tool
from tinyloop.modules.tool_loop import ToolLoop


def roll_dice():
    """Roll a dice and return the result"""
    return random.randint(1, 6)


class FinalAnswer(BaseModel):
    last_roll: int
    reached_goal: bool


system_prompt = """
You are a dice rolling assistant.
You should rool a dice until you get the number indicated in the prompt.
You should use the function roll_dice to roll the dice.
Before you roll the dice make sure to check if you have reached the goal.

In the end, you should return the last roll.
You should also return a boolean indicating if you reached the number indicated in the prompt or not.
"""

loop = ToolLoop(
    model="openai/gpt-4.1",
    system_prompt=system_prompt,
    temperature=0.1,
    output_format=FinalAnswer,
    tools=[
        Tool(
            roll_dice,
        )
    ],
)

response = loop(
    prompt="Roll a dice until you get a 6",
    parallel_tool_calls=False,
)
rprint(response)
# Out:
# LLMResponse(
#     response=FinalAnswer(last_roll=6, reached_goal=True),
#     raw_response=ModelResponse(
#         id='chatcmpl-C88aSZMTnSPEM8CYxsl336WWONVOx',
#         created=1756055668,
#         model='gpt-4.1-2025-04-14',
#         object='chat.completion',
#         system_fingerprint='fp_daf5fcc80a',
#         choices=[
#             Choices(
#                 finish_reason='stop',
#                 index=0,
#                 message=Message(
#                     content='{"last_roll":6,"reached_goal":true}',
#                     role='assistant',
#                     tool_calls=None,
#                     function_call=None,
#                     provider_specific_fields={'refusal': None},
#                     annotations=[]
#                 ),
#                 provider_specific_fields={}
#             )
#         ],
#         usage=Usage(
#             completion_tokens=12,
#             prompt_tokens=289,
#             total_tokens=301,
#             completion_tokens_details=CompletionTokensDetailsWrapper(
#                 accepted_prediction_tokens=0,
#                 audio_tokens=0,
#                 reasoning_tokens=0,
#                 rejected_prediction_tokens=0,
#                 text_tokens=None
#             ),
#             prompt_tokens_details=PromptTokensDetailsWrapper(
#                 audio_tokens=0,
#                 cached_tokens=0,
#                 text_tokens=None,
#                 image_tokens=None
#             )
#         ),
#         service_tier='default'
#     ),
#     tool_calls=None,
#     message_history=[
#         {
#             'role': 'system',
#             'content': '\nYou are a dice rolling assistant.\nYou should rool a dice until you get the number
# indicated in the prompt.\nYou should use the function roll_dice to roll the dice.\nBefore you roll the dice make
# sure to check if you have reached the goal.\n\nIn the end, you should return the last roll.\nYou should also return
# a boolean indicating if you reached the number indicated in the prompt or not.\n'
#         },
#         {'role': 'user', 'content': 'Roll a dice until you get a 6'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_lON7Nlqmv9z8vPWZBNkrJYlm',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_lON7Nlqmv9z8vPWZBNkrJYlm', 'role': 'tool', 'name': 'roll_dice', 'content': '6'},
#         {
#             'role': 'assistant',
#             'content': 'I rolled the dice and got a 6 on the first try.\n\nLast roll: 6\nReached the goal: True'
#         },
#         {'role': 'assistant', 'content': 'Last roll: 6\nReached the goal: True'},
#         {
#             'role': 'assistant',
#             'content': 'I rolled the dice and got a 6.\n\nLast roll: 6\nReached the goal: True'
#         },
#         {
#             'role': 'assistant',
#             'content': 'I rolled the dice and got a 6 on the first try.\n\nLast roll: 6\nReached the goal: True'
#         },
#         {'role': 'assistant', 'content': '{"last_roll":6,"reached_goal":true}'}
#     ],
#     cost=0.0006739999999999999,
#     hidden_fields={
#         'custom_llm_provider': 'openai',
#         'region_name': None,
#         'additional_headers': {
#             'x-ratelimit-limit-requests': '10000',
#             'x-ratelimit-remaining-requests': '9999',
#             'x-ratelimit-limit-tokens': '2000000',
#             'x-ratelimit-remaining-tokens': '1999819',
#             'llm_provider-date': 'Sun, 24 Aug 2025 17:14:28 GMT',
#             'llm_provider-content-type': 'application/json',
#             'llm_provider-transfer-encoding': 'chunked',
#             'llm_provider-connection': 'keep-alive',
#             'llm_provider-access-control-expose-headers': 'X-Request-ID',
#             'llm_provider-openai-organization': 'lfm-l6lfkw',
#             'llm_provider-openai-processing-ms': '357',
#             'llm_provider-openai-project': 'proj_7yoQfLIduKm5aSVPH3fNz0C9',
#             'llm_provider-openai-version': '2020-10-01',
#             'llm_provider-x-envoy-upstream-service-time': '372',
#             'llm_provider-x-ratelimit-limit-requests': '10000',
#             'llm_provider-x-ratelimit-limit-tokens': '2000000',
#             'llm_provider-x-ratelimit-remaining-requests': '9999',
#             'llm_provider-x-ratelimit-remaining-tokens': '1999819',
#             'llm_provider-x-ratelimit-reset-requests': '6ms',
#             'llm_provider-x-ratelimit-reset-tokens': '5ms',
#             'llm_provider-x-request-id': 'req_6709a74e03424ae89e281827da562e4e',
#             'llm_provider-cf-cache-status': 'DYNAMIC',
#             'llm_provider-strict-transport-security': 'max-age=31536000; includeSubDomains; preload',
#             'llm_provider-x-content-type-options': 'nosniff',
#             'llm_provider-server': 'cloudflare',
#             'llm_provider-cf-ray': '97447c751e6801da-YYC',
#             'llm_provider-content-encoding': 'gzip',
#             'llm_provider-alt-svc': 'h3=":443"; ma=86400'
#         },
#         'optional_params': {
#             'temperature': 0.1,
#             'stream': False,
#             'response_format': {
#                 'type': 'json_schema',
#                 'json_schema': {
#                     'schema': {
#                         'properties': {
#                             'last_roll': {'title': 'Last Roll', 'type': 'integer'},
#                             'reached_goal': {'title': 'Reached Goal', 'type': 'boolean'}
#                         },
#                         'required': ['last_roll', 'reached_goal'],
#                         'title': 'FinalAnswer',
#                         'type': 'object',
#                         'additionalProperties': False
#                     },
#                     'name': 'FinalAnswer',
#                     'strict': True
#                 }
#             },
#             'extra_body': {}
#         },
#         'litellm_call_id': '205b46a0-b065-483b-b6fd-fa11a83c555f',
#         'api_base': 'https://api.openai.com',
#         'model_id': None,
#         'response_cost': 0.0006739999999999999,
#         'litellm_model_name': 'openai/gpt-4.1',
#         'litellm_overhead_time_ms': 8.705,
#         '_response_ms': 494.016
#     }
# )
# Trace(trace_id=tr-11ba51dfc44eeff5e74618e58788d9dc)

# %% [markdown]
# #### Async

# %%
from pydantic import BaseModel
from tinyloop.features.function_calling import Tool
from tinyloop.modules.tool_loop import ToolLoop
import asyncio


async def roll_dice():
    """Roll a dice and return the result"""
    await asyncio.sleep(1)
    return random.randint(1, 6)


class FinalAnswer(BaseModel):
    last_roll: int
    reached_goal: bool


system_prompt = """
You are a dice rolling assistant.
You should rool a dice until you get the number indicated in the prompt.
You should use the function roll_dice to roll the dice.
Before you roll the dice make sure to check if you have reached the goal.

In the end, you should return the last roll.
You should also return a boolean indicating if you reached the number indicated in the prompt or not.
"""

loop = ToolLoop(
    model="openai/gpt-4.1",
    system_prompt=system_prompt,
    temperature=0.1,
    output_format=FinalAnswer,
    tools=[
        Tool(
            roll_dice,
        )
    ],
)

response = await loop.acall(
    prompt="Roll a dice until you get a 6",
    parallel_tool_calls=False,
)
rprint(response)
# Out:
# LLMResponse(
#     response=FinalAnswer(last_roll=3, reached_goal=False),
#     raw_response=ModelResponse(
#         id='chatcmpl-C88alGetsXo4Y9WVUxJvdbTq5gtPt',
#         created=1756055687,
#         model='gpt-4.1-2025-04-14',
#         object='chat.completion',
#         system_fingerprint='fp_daf5fcc80a',
#         choices=[
#             Choices(
#                 finish_reason='stop',
#                 index=0,
#                 message=Message(
#                     content='{"last_roll":3,"reached_goal":false}',
#                     role='assistant',
#                     tool_calls=None,
#                     function_call=None,
#                     provider_specific_fields={'refusal': None},
#                     annotations=[]
#                 ),
#                 provider_specific_fields={}
#             )
#         ],
#         usage=Usage(
#             completion_tokens=12,
#             prompt_tokens=259,
#             total_tokens=271,
#             completion_tokens_details=CompletionTokensDetailsWrapper(
#                 accepted_prediction_tokens=0,
#                 audio_tokens=0,
#                 reasoning_tokens=0,
#                 rejected_prediction_tokens=0,
#                 text_tokens=None
#             ),
#             prompt_tokens_details=PromptTokensDetailsWrapper(
#                 audio_tokens=0,
#                 cached_tokens=0,
#                 text_tokens=None,
#                 image_tokens=None
#             )
#         ),
#         service_tier='default'
#     ),
#     tool_calls=None,
#     message_history=[
#         {
#             'role': 'system',
#             'content': '\nYou are a dice rolling assistant.\nYou should rool a dice until you get the number
# indicated in the prompt.\nYou should use the function roll_dice to roll the dice.\nBefore you roll the dice make
# sure to check if you have reached the goal.\n\nIn the end, you should return the last roll.\nYou should also return
# a boolean indicating if you reached the number indicated in the prompt or not.\n'
#         },
#         {'role': 'user', 'content': 'Roll a dice until you get a 6'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_FvCQWqph0ML4THPwv4jqU3JV',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_FvCQWqph0ML4THPwv4jqU3JV', 'role': 'tool', 'name': 'roll_dice', 'content': '2'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_syJ65xYgN6EPTIGKe4sdram5',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_syJ65xYgN6EPTIGKe4sdram5', 'role': 'tool', 'name': 'roll_dice', 'content': '3'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_vUhlPvM3C7oqLIM9sM6TJQXj',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_vUhlPvM3C7oqLIM9sM6TJQXj', 'role': 'tool', 'name': 'roll_dice', 'content': '1'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_qC5XxCT6HxDiJQFAcfY6mgEl',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_qC5XxCT6HxDiJQFAcfY6mgEl', 'role': 'tool', 'name': 'roll_dice', 'content': '1'},
#         {
#             'role': 'assistant',
#             'content': '',
#             'tool_calls': [
#                 {
#                     'id': 'call_i9LITo4KhdDWwau354JbDSit',
#                     'type': 'function',
#                     'function': {'name': 'roll_dice', 'arguments': '{}'}
#                 }
#             ]
#         },
#         {'tool_call_id': 'call_i9LITo4KhdDWwau354JbDSit', 'role': 'tool', 'name': 'roll_dice', 'content': '3'},
#         {'role': 'assistant', 'content': '{"last_roll":3,"reached_goal":false}'}
#     ],
#     cost=0.000614,
#     hidden_fields={
#         'custom_llm_provider': 'openai',
#         'region_name': None,
#         'headers': {
#             'date': 'Sun, 24 Aug 2025 17:14:47 GMT',
#             'content-type': 'application/json',
#             'transfer-encoding': 'chunked',
#             'connection': 'keep-alive',
#             'access-control-expose-headers': 'X-Request-ID',
#             'openai-organization': 'lfm-l6lfkw',
#             'openai-processing-ms': '434',
#             'openai-project': 'proj_7yoQfLIduKm5aSVPH3fNz0C9',
#             'openai-version': '2020-10-01',
#             'x-envoy-upstream-service-time': '451',
#             'x-ratelimit-limit-requests': '10000',
#             'x-ratelimit-limit-tokens': '2000000',
#             'x-ratelimit-remaining-requests': '9999',
#             'x-ratelimit-remaining-tokens': '1999882',
#             'x-ratelimit-reset-requests': '6ms',
#             'x-ratelimit-reset-tokens': '3ms',
#             'x-request-id': 'req_778b14719b93463ba87511d21506cd2f',
#             'cf-cache-status': 'DYNAMIC',
#             'strict-transport-security': 'max-age=31536000; includeSubDomains; preload',
#             'x-content-type-options': 'nosniff',
#             'server': 'cloudflare',
#             'cf-ray': '97447cee496801e4-YYC',
#             'content-encoding': 'gzip',
#             'alt-svc': 'h3=":443"; ma=86400'
#         },
#         'additional_headers': {
#             'x-ratelimit-limit-requests': '10000',
#             'x-ratelimit-remaining-requests': '9999',
#             'x-ratelimit-limit-tokens': '2000000',
#             'x-ratelimit-remaining-tokens': '1999882',
#             'llm_provider-date': 'Sun, 24 Aug 2025 17:14:47 GMT',
#             'llm_provider-content-type': 'application/json',
#             'llm_provider-transfer-encoding': 'chunked',
#             'llm_provider-connection': 'keep-alive',
#             'llm_provider-access-control-expose-headers': 'X-Request-ID',
#             'llm_provider-openai-organization': 'lfm-l6lfkw',
#             'llm_provider-openai-processing-ms': '434',
#             'llm_provider-openai-project': 'proj_7yoQfLIduKm5aSVPH3fNz0C9',
#             'llm_provider-openai-version': '2020-10-01',
#             'llm_provider-x-envoy-upstream-service-time': '451',
#             'llm_provider-x-ratelimit-limit-requests': '10000',
#             'llm_provider-x-ratelimit-limit-tokens': '2000000',
#             'llm_provider-x-ratelimit-remaining-requests': '9999',
#             'llm_provider-x-ratelimit-remaining-tokens': '1999882',
#             'llm_provider-x-ratelimit-reset-requests': '6ms',
#             'llm_provider-x-ratelimit-reset-tokens': '3ms',
#             'llm_provider-x-request-id': 'req_778b14719b93463ba87511d21506cd2f',
#             'llm_provider-cf-cache-status': 'DYNAMIC',
#             'llm_provider-strict-transport-security': 'max-age=31536000; includeSubDomains; preload',
#             'llm_provider-x-content-type-options': 'nosniff',
#             'llm_provider-server': 'cloudflare',
#             'llm_provider-cf-ray': '97447cee496801e4-YYC',
#             'llm_provider-content-encoding': 'gzip',
#             'llm_provider-alt-svc': 'h3=":443"; ma=86400'
#         },
#         'optional_params': {
#             'temperature': 0.1,
#             'stream': False,
#             'response_format': {
#                 'type': 'json_schema',
#                 'json_schema': {
#                     'schema': {
#                         'properties': {
#                             'last_roll': {'title': 'Last Roll', 'type': 'integer'},
#                             'reached_goal': {'title': 'Reached Goal', 'type': 'boolean'}
#                         },
#                         'required': ['last_roll', 'reached_goal'],
#                         'title': 'FinalAnswer',
#                         'type': 'object',
#                         'additionalProperties': False
#                     },
#                     'name': 'FinalAnswer',
#                     'strict': True
#                 }
#             },
#             'extra_body': {}
#         },
#         'litellm_call_id': '2231f749-be2e-4ad3-a370-686b29c1ab33',
#         'api_base': 'https://api.openai.com',
#         'model_id': None,
#         'response_cost': 0.000614,
#         'litellm_model_name': 'openai/gpt-4.1',
#         'litellm_overhead_time_ms': 2.88,
#         '_response_ms': 574.977
#     }
# )
# Trace(trace_id=tr-0b75289bcbd8c4cd2daf250d89df0bdd)

# %% [markdown]
# ### Generate

# %% [markdown]
# #### Sync

# %%
from tinyloop.modules.generate import Generate
from pydantic import BaseModel
from typing import List


class Character(BaseModel):
    name: str
    description: str
    image: str


class Characters(BaseModel):
    characters: List[Character]


generate = Generate(
    model="openai/gpt-4.1-nano", temperature=0.1, output_format=Characters
)

response = generate(prompt="Give me 3 harry potter characters")
rprint(response)

# %% [markdown]
# #### Async

# %%
from tinyloop.modules.generate import Generate
from pydantic import BaseModel
from typing import List


class Character(BaseModel):
    name: str
    description: str
    image: str


class Characters(BaseModel):
    characters: List[Character]


generate = Generate(
    model="openai/gpt-4.1-nano", temperature=0.1, output_format=Characters
)

response = await generate.acall(prompt="Give me 3 harry potter characters")
rprint(response)
